# %% [markdown]
# # Applied Statistics Final Project
# ## Ronald Adomako
# 12/9/19

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.regression.linear_model as sm

import geopandas as gpd
import cartopy.io.shapereader as shprdr

# %matplotlib inline

# %%
DB.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20152 entries, 0 to 20151
# Data columns (total 21 columns):
# year      20152 non-null int64
# month     20152 non-null int64
# day       20152 non-null int64
# hour      20152 non-null float64
# LAT       20152 non-null float64
# LON       20152 non-null float64
# ISST      20152 non-null float64
# OSST      20152 non-null float64
# OERR      20152 non-null float64
# SI        0 non-null float64
# ICflag    20152 non-null int64
# DS        0 non-null float64
# VS        0 non-null float64
# WDIR      0 non-null float64
# WSPD      0 non-null float64
# SLP       7305 non-null float64
# AT        0 non-null float64
# WBT       0 non-null float64
# DPT       0 non-null float64
# CLT       0 non-null float64
# CLL       0 non-null float64
# dtypes: float64(17), int64(4)
# memory usage: 3.2 MB

# %%
column = ["year", "month", "day", "hour", "LAT", "LON", "ISST","OSST",
 "OERR", "SI", "ICflag", "DS", "VS", "WDIR", "WSPD", "SLP",
 "AT", "WBT", "DPT", "CLT", "CLL"]
len(column)
# Out:
# 21

# %%
DB = pd.read_csv("DB_33944.csv", names = column)
MB = pd.read_csv("MB_62413.csv", names = column)
SH = pd.read_csv("SH_GDLS.csv", names = column)

# %%
DB.head()
# Out:
#    year  month  day   hour    LAT     LON  ISST  OSST  OERR  SI  ...  DS  VS  \
# 0  1995      4   11  15.80 -54.43  308.89   5.8  5.89  0.37 NaN  ... NaN NaN
# 1  1995      4   11  23.80 -54.40  309.03   5.8  5.87  0.46 NaN  ... NaN NaN
# 2  1995      4   12   0.80 -54.39  309.06   5.8  5.75  0.46 NaN  ... NaN NaN
# 3  1995      4   12   7.82 -54.39  309.20   5.8  5.70  0.46 NaN  ... NaN NaN
# 4  1995      4   12   8.80 -54.38  309.25   5.8  5.69  0.45 NaN  ... NaN NaN
#
#    WDIR  WSPD     SLP  AT  WBT  DPT  CLT  CLL
# 0   NaN   NaN  1001.0 NaN  NaN  NaN  NaN  NaN
# 1   NaN   NaN  1006.0 NaN  NaN  NaN  NaN  NaN
# 2   NaN   NaN  1006.8 NaN  NaN  NaN  NaN  NaN
# 3   NaN   NaN  1007.6 NaN  NaN  NaN  NaN  NaN
# 4   NaN   NaN  1007.8 NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
HQ_DB = sum(DB['ICflag']==1)
print(HQ_DB)
# Out:
# 19674

# %%
total_DB = DB['ICflag'].count()
LQ_DB = total_DB - HQ_DB
print(LQ_DB)
# Out:
# 478

# %%
print('High quality flag percentage of drifting buoys: ',round(100*(HQ_DB/total_DB)),'%')
# Out:
# High quality flag percentage of drifting buoys:  98.0 %

# %%
x_DB=np.array(DB['OSST']) 
y_DB=np.array(DB['ISST'])

# %%
print(x_DB.shape)
print(y_DB.shape)
_ = plt.scatter(x_DB,y_DB,alpha=0.1)
_ = plt.xlabel('OSST (°C)')
_ = plt.ylabel('ISST (°C)')
_ = plt.title('Drifting Buoy\'s Satellite (OSST) v. \n Ship (ISST) heat readings',
             fontweight='bold')
lm = sm.OLS(y_DB,x_DB).fit()
_ = plt.text(5, 15, 'R^2 = ' + str(round(lm.rsquared,3)), horizontalalignment='center', 
             verticalalignment='center')
# Out:
# (20152,)
# (20152,)

# %%
lm = sm.OLS(y_DB,x_DB).fit()

# %%
print("The Drifting Buoy's Rsquared values is " + str(lm.rsquared))
# Out:
# The Drifting Buoy's Rsquared values is 0.997114546636005

# %%
def makePlot(buoyStr,df):
    
    'Examine quality flags for ship data'
    HQ_flag = sum(df['ICflag']==1)
    total_flag = df['ICflag'].count()
    LQ_flag = total_flag - HQ_flag
    
    print('High quality flag percentage of '+ buoyStr + '\'s: ',
          round(100*(HQ_flag/total_flag),4),'%')
    
    z = df[['OSST','ISST']]
    z = z.dropna()
    
    x = np.array(z['OSST']) 
    y = np.array(z['ISST'])
    
    _ = plt.subplots()
    _ = plt.scatter(x, y, alpha=0.05,s=1)
    _ = plt.xlabel('OSST (°C)')
    _ = plt.ylabel('ISST (°C)')
    _ = plt.title('Satellite (OSST) v. '+ buoyStr +'\'s v. \n InSutu (ISST) heat readings',
                 fontweight='bold')
    lm = sm.OLS(y, x)
    lm_fit = lm.fit()
    lm = None
    _ = plt.text(5, 15, 'R^2 = ' + str(round(lm_fit.rsquared,3)), 
                 horizontalalignment='center', verticalalignment='center')
    plt.savefig(buoyStr)
    return

# %%
for file in [DB,MB,SH]:
    if file is DB:
        buoyStr = 'Drifting Buoy'
    elif file is MB:
        buoyStr = 'Mooring Buoy'
    else:
        buoyStr = 'Ship'
    
    makePlot(buoyStr,file)
# Out:
# High quality flag percentage of Drifting Buoy's:  97.628 %
# High quality flag percentage of Mooring Buoy's:  99.7941 %
# High quality flag percentage of Ship's:  99.9061 %

# %%
x_MB=np.array(MB['OSST']) 
y_MB=np.array(MB['ISST'])

z_MB = MB[['OSST','ISST']]
print(z_MB.count(), 'max')
print('...')
z_MB = z_MB.dropna()
print(z_MB.count(), 'cleaned')
print('...')
print(z_MB)
# Out:
# OSST    9225
# ISST    9226
# dtype: int64 max
# ...
# OSST    9225
# ISST    9225
# dtype: int64 cleaned
# ...
#        OSST  ISST
# 0     10.83  10.6
# 1     10.83  10.6
# 2     10.83  10.6
# 3     10.37  10.7
# 4     10.37  10.6
# 5     10.37  10.6
# 6     10.27  10.4
# 7     10.27  10.3
# 8     10.24  10.1
# 9     10.05  10.0
# 10    10.05  10.0
# 11    10.05  10.0
# 12    10.34   9.9
# 13    10.34  10.0
# 14    10.34  10.0
# 15    10.43  10.0
# 16    10.43  10.0
# 17    10.43   9.9
# 18    10.43   9.9
# 19    10.45   9.9
# 20    10.45   9.8
# 21    10.39   9.8
# 22    10.39   9.7
# 23    10.39   9.7
# 24    10.39   9.7
# 25    10.39   9.7
# 26    10.42   9.7
# 27    10.46   9.7
# 28    10.46   9.7
# 29    10.46   9.7
# ...     ...   ...
# 9196  13.57  14.2
# 9197  13.57  14.2
# 9198  13.57  14.2
# 9199  13.57  14.1
# 9200  13.76  14.2
# 9201  13.76  14.2
# 9202  13.76  14.2
# 9203  13.76  14.2
# 9204  13.76  14.2
# 9205  13.76  14.2
# 9206  13.76  14.2
# 9207  13.76  14.3
# 9208  13.82  14.3
# 9209  13.82  14.3
# 9210  13.82  14.3
# 9211  13.82  14.3
# 9212  13.82  14.3
# 9213  13.82  14.3
# 9214  13.82  14.3
# 9215  13.82  14.4
# 9216  14.12  14.3
# 9217  14.12  14.3
# 9218  14.12  14.4
# 9219  14.12  14.4
# 9220  14.12  14.4
# 9221  14.12  14.4
# 9222  14.12  14.4
# 9223  14.12  14.4
# 9224  14.20  14.4
# 9225  14.20  14.5
#
# [9225 rows x 2 columns]

# %%
x_DB=np.array(DB['LON']) 
y_DB=np.array(DB['LAT'])

import cartopy.crs as ccrs

plt.figure(figsize=(18,8))
ax = plt.axes(projection=ccrs.Mercator())
ax.coastlines(resolution='10m')
plt.scatter(x_DB,y_DB)
